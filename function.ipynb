# %% [markdown]
# #THEORY QUESTION

# %% [markdown]
#  1. What is the difference between a function and a method in Python?
#  >>Function: A function is a block of code that performs a specific task and is defined using the def keyword. It can be used independently.
#
#  * Method: A method is a function that is associated with an object (usually a class) and is called using dot (.) notation.
# # Function
#  * def greet(name):
#    * return "Hello " + name
#
# * print(greet("Aparna"))
#
# # Method
# * name = "Aparna"
# * print(name.upper())  # upper() is a string method
#   * APARNA

# %% [markdown]
#  2. Explain the concept of function arguments and parameters in Python.
#  >>Parameters are the variables listed inside the parentheses in the function definition.
#
#  *  Arguments are the values passed to the function when it is called.
#
#
# #example:
#
#  * def add(x, y):  # x and y are parameters
#   *  return x + y
#
#   * result = add(3, 4)  # 3 and 4 are arguments

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
# >>Ways to define:
#
# * Using def keyword
#
# * Using lambda keyword
#
#  Ways to call:
#
#  * Directly by function name with arguments
#
#  * Using a reference (function stored in a variable)
#
#  * Recursively
#
#  # Standard function
#  * def square(x):
#    * return x * x
#
#  * print(square(5))
#
# # Lambda function
#  * square_lambda = lambda x: x * x
#  * print(square_lambda(5))

# %% [markdown]
# 4.What is the purpose of the `return` statement in a Python function?
# >>The return statement is used to send the result of a function back to the caller and end the function execution.
#
#
#  * def multiply(a, b):
#    *  return a * b
#
# * print(multiply(3, 4))  # Output: 12

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#  >> * Iterable: An object capable of returning its members one at a time (e.g., list, tuple, string).
#
#  * Iterator: An object with a __next__() method that returns the next item from the iterable
#   * my_list = [1, 2, 3]  # iterable
#   * it = iter(my_list)   # creating iterator
#
#     * print(next(it))  # Output: 1

# %% [markdown]
#  6. Explain the concept of generators in Python and how they are defined.
#  >>Generators are functions that return an iterator and allow iteration one value at a time using the yield keyword.
# They maintain state between iteration .
#
#
# *  def countdown(n):
#     while n > 0:
#         yield n
#         n -= 1
#
# *  for i in countdown(3):
#     print(i)

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
# >>  * Memory efficient: They yield one item at a time.
#
#    * Faster for large datasets: Do not store entire data in memory.
#
#    * Statefulness: They pause and resume from where they left off.

# %% [markdown]
#  8. What is a lambda function in Python and when is it typically used?
#  >>A lambda function is an anonymous, single-expression function defined using the lambda keyword.
#
#     * Used when: You need a small function for a short time (often used with map, filter, sorted).
#
# Example:
# * double = lambda x: x * 2
#   * print(double(4))  # Output: 8

# %% [markdown]
# 9. Explain the purpose and usage of the `map()` function in Python.
# >> * map() applies a function to every item in an iterable.
#
#   * Returns a map object (which is an iterator).
#
#
# *  nums = [1, 2, 3, 4]
# * squared = map(lambda x: x**2, nums)
# * print(list(squared))  # Output: [1, 4, 9, 16]

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# >> map applies a function to all items .
#  * filter item based on the condition.
#  * reduce Applies function cumulatively to reduce to a single value.
#
#  from functools import reduce
#
#  * nums = [1, 2, 3, 4, 5]
#
#  * mapped = map(lambda x: x * 2, nums)     # [2, 4, 6, 8, 10]
#  * filtered = filter(lambda x: x % 2 == 0, nums)  # [2, 4]
#  * reduced = reduce(lambda x, y: x + y, nums)     # 15
#
# * print(list(mapped))
# * print(list(filtered))
# * print(reduced)

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list [47,11,42,13]?
#  >>![reduce lambda.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # practical questions

# %%
#Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
def sum_even_numbers(numbers):
    sum = 0
    for num in numbers:
        if num % 2 == 0:
            sum += num
    return sum

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string
def reverse_string(string):
  return string[::-1]

# %%
# Implement a Python function that takes a list of integers and returns a new list containing the squares of each numbers.
def square_numbers(numbers):
  squares = []
  for num in numbers:
    squares.append(num**2)
  return squares

# %%
#Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(number):
  if number < 2:
    return False
  for i in range(2, number):
    if number % i == 0:
      return False
  return True

# %%
#Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

class FibonacciIterator:
    def __init__(self, terms):
        self.terms = terms
        self.current_term = 0
        self.a = 0
        self.b = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.current_term < self.terms:
            if self.current_term == 0:
                self.current_term += 1
                return self.a
            elif self.current_term == 1:
                self.current_term += 1
                return self.b
            else:
                next_fib = self.a + self.b
                self.a = self.b
                self.b = next_fib
                self.current_term += 1
                return next_fib
        else:
            raise StopIteration

# Example usage:
fib_iterator = FibonacciIterator(10)
for number in fib_iterator:
    print(number)

# %%
#Write a generator function in Python that yields the powers of 2 up to a given exponent.
def powers_of_2(exponent):
    for i in range(exponent + 1):
        yield 2 ** i

# %%
# Implement a generator function that reads a file line by line and yields each line as a string
def read_file_lines(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line

# %%
# Use a lambda function in Python to sort a list of tuples based on the second element of each tuple
data = [('apple', 3), ('banana', 1), ('cherry', 2)]
sorted_data = sorted(data, key=lambda x: x[1])
print(sorted_data)
# Out:
# [('banana', 1), ('cherry', 2), ('apple', 3)]

# %%
# Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit
# Function to convert Celsius to Fahrenheit
def celsius_to_fahrenheit(c):
    return (c * 9/5) + 32

# List of temperatures in Celsius
celsius_temps = [0, 10, 20, 30, 40, 100]

# Use map() to apply the conversion function to each temperature
fahrenheit_temps = list(map(celsius_to_fahrenheit, celsius_temps))

# Print the results
print("Celsius temperatures:", celsius_temps)
print("Fahrenheit temperatures:", fahrenheit_temps)
# Out:
# Celsius temperatures: [0, 10, 20, 30, 40, 100]
# Fahrenheit temperatures: [32.0, 50.0, 68.0, 86.0, 104.0, 212.0]

# %%
# Create a Python program that uses `filter()` to remove all the vowels from a given string
# Input string
input_string = "Hello, how are you doing today?"

# Use filter() with lambda to remove vowels
filtered_string = ''.join(filter(lambda char: char.lower() not in 'aeiou', input_string))

# Print the result
print("Original string:", input_string)
print("String without vowels:", filtered_string)
# Out:
# Original string: Hello, how are you doing today?
# String without vowels: Hll, hw r y dng tdy?

# %%
# 11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
#product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
#order is smaller than 100,00 €.
 #Write a Python program using lambda and map

# Data: [Order Number, Book Title & Author, Quantity, Price per Item]
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# Function using map + lambda
order_totals = list(map(lambda x: (x[0], x[2] * x[3] if x[2] * x[3] >= 100 else x[2] * x[3] + 10), orders))

print(order_totals)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]

# %% [markdown]
# #THANK YOU SIR
